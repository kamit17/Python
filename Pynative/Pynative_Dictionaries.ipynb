# %%
#creating a dictionary using {}
person = {"name":"Jesse","Country":"USA","telephone": "86753099"}
print(person)

#create a dictionary using dict()

person = dict ({"name":"Jesse","Country":"USA","telephone": "86753099"})
print(person)
#emptydict
emptydict = {}
print(type(emptydict))

# %%
#Accessing elements of a dictionary
person = {"name":"Jesse","Country":"USA","telephone": "86753099"}

print("--------All the keys------")
#get all the keys
print(person.keys())
print(type(person.keys()))
print()

print("--------All the key value pairs ------")
#get all  key-value painrs
print(person.items())
print(type(person.items()))
print()

print("--------All the values------")
#get all the values
print(person.values())
print(type(person.values()))
print()
print("--------All the key value pairs ------")
#get all  key-value painrs
print(person.items())
print(type(person.items()))
print()

print("--------Acess Values ------")
#acess value using key name in []
print(person['name'])

#get key value using key name in get()
print(person.get('telephone'))

# %%
#iterating a dictionary
#iterate using a for loop and access the individual keys and their corresponding values

person = {"name":"Jesse","Country":"USA","telephone": "86753099"}

#iterating the dictionary using for-loop
print('key',':','value')
for key in person:
    print(key,':',person[key])

#using items() method
print("-----------Using items() method-------")
print('key',':','value')
for key,value in person.items():
    print(key,':',value)

#count number of keys present in a dictionary
print(len(person))
print()
print("-----Adding items to the dictionary----")

#update dictionary by adding two new keys
person["weight"] = 50
person.update({"height": 6})

person.update([("city", "Texas"), ("company", "Google",)])

print(person)

# %%
#set default value to a key
person_details = {"name":"Jesse","Country":"USA","telephone": "86753099"}


#set default value if key doesn't exist
person_details.setdefault('state','Texas')

#key doesn't exist and value not mentioned.default none
person_details.setdefault("ZIP")

#key exists and value mentioned, does'nt change value
person_details.setdefault('Country','Canada')

#display dicitonary
for key,value in person_details.items():
    print(key,':',value)

# %%
#modify value of the dictionary 
#using keyname  -- directl assign value by using its key name.
#using update method -- pass key-value pari to change the value.

person = {"name": "Jesse","Country":"USA"}

#updating the country name
person["Country"] = "Canada"
print(person['Country'])

#using update method
person.update({"Country":"USA"})

print(person['Country'])

# %%
#removing items from a dictionary

person = {"name":"Jesse","Country":"USA","telephone": "86753099",'weight': 50, 'height': 6}

print(person.items())
#remove last inserted item from the dictionary
deleted_item = person.popitem()
print(deleted_item)
print(key)
#Remove key from the dictionary
deleted_item = person.pop('telephone')
print(f"Deleted item is {deleted_item}")

#delete key 'weight'
del person['weight']
print(person)

#remove all items from the dictionary
person.clear()
print(person)

#delete the eintire dictionary
del person

# %%
#check if a key exists
person = {"name":"Jesse","Country":"USA","telephone": "86753099",'weight': 50, 'height': 6}

#get he list of keys and check if country key is present or not
key_name = 'Country'
if key_name in person.keys():
    print("country name is",person[key_name])
else:
    print("key not found")

# %%
#join two dictionary
#using update method
dict1 = {'Jessa': 70, 'Arul': 80, 'Emma': 55}
dict2 = {'Kelly': 68, 'Harry': 50, 'Olivia': 66}

#copy second dictionary into first dictionary
dict1.update(dict2)
print(dict1)

#using **kwargs to unpack
#unpack dictionary and add to another dictionary
student_dict1 = {'Aadya': 1, 'Arul': 2, }
student_dict2 = {'Harry': 5, 'Olivia': 6}
student_dict3 = {'Nancy': 7, 'Perry': 9}

#join three dictionaries
student_dict = {**student_dict1,**student_dict2,**student_dict3}
print(student_dict)

# %%
#join two dictionaries having few items in common.0-- common key is overriden in first dictionary
dict1 = {'Jessa': 70, 'Arul': 80, 'Emma': 55}
dict2 = {'Kelly': 68, 'Harry': 50, 'Emma': 66}


dict1.update(dict2)
print(dict1['Emma'])

# %%
#copy a dictionary
#using copy

dict1 = {'Jesse': 70,'Emma' : 55}
dict2 = dict1.copy()

print(dict2)

#using dict() constructor
dict3 = dict(dict1)
print(dict3)

#copy using itesm() method
dict4 = dict(dict1.items())
print(dict4)

# %%
#nested Dictionary
address = {"state": "Texas","city":"Houston"}

person = {"name":"Jesse","Country":"USA","telephone": "86753099",'weight': 50, 'height': 6,'address' : address}

print('person Details:',person)

# Get nested dictionary key 'city'
print("City:", person['address']['city'])

#iterating outer dictionary
print("Person Details")
for key,value in person.items():
    if key == "address":
        #iterating through nested dictionary
        print("Person Address")
        for nested_key, nested_value in value.items():
            print(nested_key,':', nested_value)
    else:
        print(key,':',value)

# %%
#Add multiple dictionaries inside a single dictionary

# in order to access nested dictionary values, we have to pass the outer dictionary key, followed by the individual dictionary key

# each dictionary will store data of a single student
jessa = {'name': 'Jessa', 'state': 'Texas', 'city': 'Houston', 'marks': 75}
emma = {'name': 'Emma', 'state': 'Texas', 'city': 'Dallas', 'marks': 60}
kelly = {'name': 'Kelly', 'state': 'Texas', 'city': 'Austin', 'marks': 85}

#outer dictionary to store all student dictionaries
class_six = {'student1': jessa, 'student2': emma, 'student3': kelly}


#get student 3's name and marks
print("Student 3 name: ",class_six['student3']['name'])
print("Student 3 marks:",class_six['student3']['marks'])

#iterating outer dictionary

print("Class Details")
for key,value in class_six.items():
    #iteratring through nested dictionary
    #Display each student data
    print(key)
    for nested_key,nested_value in value.items():
        print(nested_key,":",nested_value)
    print()

# %%
dict1 = {'c': 45, 'b': 95, 'a': 35}

#sorting dictionary by key
print(sorted(dict1.items()))

#sorting dict keys
print(sorted(dict1))

#sorting dictionary values
print(sorted(dict1.values()))

# %%
#Dictionary comprehension
#syntax
#output_dictionary = {key : value for key,value in iterable [if key,value condition1]}

#calculate the square of each even number from a list and store in a dictionary

numbers = [1,2,4,5,6,8]
squares = {x: x**2 for x in numbers if x %2 == 0}
print(squares)

# %%
telephone_book = [1178, 4020, 5786]
persons = ['Jessa', 'Emma', 'Kelly']

telephone_Directory = {key: value for key, value in zip(persons, telephone_book)}
print(telephone_Directory)

# %%
#max and min
dict = {1:'aaa',2:'bbb',3:'AAA'}
print('Maximum Key',max(dict)) # 3
print('Minimum Key',min(dict)) # 1

# %%
#all
#When the built-in function all() is used with the dictionary the return value will be true in the case of all – true keys and false in case one of the keys is false.

#dictionary with both 'true' keys
dict1 = {1:'True',1:'False'}

#dictionary with one false key
dict2 = {0:'True',1:'False'}

#empty dictionary
dict3= {}

#'0' is true actually
dict4 = {'0':False}

print('All True Keys::',all(dict1))
print('One False Key',all(dict2))
print('Empty Dictionary',all(dict3))
print('With 0 in single quotes',all(dict4))

# %%
#any()
#any() function will return true if dictionary keys contain anyone false which could be 0 or false. Let us see what any() method will return for the above cases.

#dictionary with both 'true' keys
dict1 = {1:'True',1:'False'}

#dictionary with one false key
dict2 = {0:'True',1:'False'}

#empty dictionary
dict3= {}

#'0' is true actually
dict4 = {'0':False}

#all false
dict5 = {0:False}

print('All True Keys::',any(dict1))
print('One False Key ::',any(dict2))
print('Empty Dictionary ::',any(dict3))
print('With 0 in single quotes ::',any(dict4))
print('all false :: ',any(dict5))
