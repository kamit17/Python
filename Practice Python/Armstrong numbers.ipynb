# %%
#Armstrong number
#If the given number is equal to the sum of the Nth power of each digit present in that integer then, that number can be a Armstrong Number
def armstrong(x):
    #initialize sum
    sum = 0
    
    #finding the sum of the cube of each digit
    temp = x
    while temp > 0:
        digit = temp % 10
        sum += digit ** 3
        temp //= 10
    if( x == sum):
        print('Num is armstrong number:')
    else:
        print('Num is not an armonstrong number:')
armstrong(371)

# %%
#Armstrong number by using the numer as a string data type

for i in range(1001):
    num = i
    result = 0
    n = len(str(i))
    while(i != 0):
        #extract the digit
        digit = i % 10
        result = result + digit ** n
        i //=10
    if num == result:
        print(num,end = ' ')

# %%
#python program for Armstrong numbers using Functions
def Armstrong_Number(num):
    #initializing sum and digits of number
    sum = 0
    n = 0
   
    
    #calculating number of individual digits
    temp = num
    while temp > 0:
        n = n + 1
        temp = temp //10
        
    #finding Armstrong number
    temp = num
    for i in range(1,temp + 1):
        remainder = temp % 10
        sum = sum + (remainder ** n)
        temp //=10
    return sum

num = int(input('\n Enter the number:'))

if ( num == Armstrong_Number(num)):
    print('{0} is Armstrong number'.format(num))
else:
    print('{0} is not an Armstrong number'.format(num))

# %%
#Check Armstrong number of n digits

num  = int(input('Enter a number: '))
#Change num to string and calculate the length
order = len(str(num)) 
#initialize sum
sum = 0

#find the sum of the cube oc each digit

temp = num
while temp > 0:
    digit = temp % 10
    sum += digit ** order
    temp //=10
#display the result
if num == sum:
    print(num,'is armstrong number')
else:
    print(num ,'is not an armstrong number')

# %%
# Armstrong number using recursion:

#defining the getSum() recursive function
def getSum(num):
    if num == 0:
        #base case
        return num
    else:
        #iterative case
        return pow((num%10),order)+ getSum(num//10)
    
#taking input and storing number in num variabl
num = int(input('Enter a number: '))

#finding order using len() and str() function

order = len(str(num))

#initializing the sum variable
sum = getSum(num)

#checking for armstrong
if sum == int(num):
    print(num,'is Armstrong')
else:
    print(num,'is not Armstrong')

# %%
#recursion Examples 2

#initializing Number of digits
sum = 0
times = 0

#calculating Number of individual digits

def count_of_digits(num):
    global times
    if(num >0):
        times = times + 1
        count_of_digits(num//10)
    return times

#Findin Armstrong number

def armstrong_number(num,times):
    global sum
    if (num > 0):
        remainder = num % 10
        sum = sum + (remainder ** times)
        armstrong_number(num//10,times)
    return sum

#user input

num = int(input('Enetr a number: '))
times = count_of_digits(num)
sum = armstrong_number(num,times)
if(num == sum):
    print(num,'is Armstrong')
else:
    print(num,'is not Armstrong')
