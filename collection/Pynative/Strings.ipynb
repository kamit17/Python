# %%
#Write a program to create a new string made of an input string’s first, middle, and last character.

input_string = "james"

first_char = input_string[0]
print(f"first_char is: {first_char}")

middle_index = len(input_string) // 2
middle_char = input_string[middle_index]
print(f"middle char is: {middle_char}")

last_char = input_string[-1]
print(f"last_char is: {last_char}")
print(f"string made from first,middle and last charcters is : {first_char+middle_char+last_char}")

# %%
#Create a string made of the middle three characters
word = "JhonDipPeta"
middle_index = len(word)//2
middle_char = word[middle_index]
print(f"middle char is: {middle_char}")

#Use string slicing to get the middle three characters starting from the middle index to the next two character
char_before = word[middle_index -1]
print(f"char before middle char is: {char_before}")
char_after = word[middle_index +1]
print(f"char after middle char is: {char_after}")
final_word = char_before + middle_char + char_after
print(f"final_word is : {final_word}")

# %%
# Append new string in the middle of a given string
str1 = "hello"
str2 = "mello"

#print(len(str1))
mi =int(len(str1)//2)

#get the characters from start till middle index
x = str1[:mi]
#print(x)

#add the characters from start till middle of str1 to str2
x = x + str2

#add the characters from the end of middle index to the last character in str1
x = x + str1[mi:]

print(x)

# %%
#Create a new string made of the first, middle, and last characters of each input string

#Given two strings, s1 and s2, write a program to return a new string made of s1 and s2’s first, middle, and last characters.
s2 = "Australia"
s1 = "Japan"
# First characters
s1_first = s1[0]
s2_first = s2[0]

# Middle characters
s1_middle = s1[len(s1)//2]
s2_middle = s2[len(s2)//2]

# Last characters
s1_last = s1[-1]
s2_last = s2[-1]

# Combine
new_string = s1_first + s1_middle + s1_last + s2_first + s2_middle + s2_last
print(new_string)

# %%
#Arrange string characters such that lowercase letters should come first

str1 = "Pynative"

lower = []
upper = []

for char in str1:
    if char.islower():
        lower.append(char)
    else:
        upper.append(char)

sorted_str = ''.join(lower + upper)
print('Result:', sorted_str)

# %%
#Count all letters, digits, and special symbols from a given string

str1 = "P@#yn26at^&i5ve"

char_count = 0
digit_count = 0
symbol_count = 0
for char in str1:
    if char.isalpha():
        char_count +=1
    elif char.isdigit():
        digit_count +=1
    else:
        symbol_count +=1
        
print(f"Chars = {char_count}\nDigits = {digit_count}\nSymbol = {symbol_count}")

# %% [markdown]
# '''
# Create a mixed String using the following rules
#
# Given two strings, s1 and s2. Write a program to create a new string s3 made of the first char of s1, then the last char of s2, Next, the second
# char of s1 and second last char of s2, and so on. Any leftover chars go at the end of the result.
#
#
# Given:
#
# s1 = "Abc"
# s2 = "Xyz"
#
# Expected Output:
#
# AzbycX
# '''
#
# extract the first char of s1, extract the last char of s2.
# extract the second char of s1 , extrac the second last char of s2

# %%
s1 = "Abc"
s2 = "Xyz"
#result counter
result = " "

#reverse s2
s2 = s2[::-1]

#index counter
i = 0

while i < len(s1) and i < len(s2):
    if i < len(s1):
        result +=s1[i]
    if i < len(s2):
        result += s2[i]
    i +=1

print(result)

# %% [markdown]
# String characters balance Test
#
# Write a program to check if two strings are balanced. For example, strings s1 and s2 are balanced if all the characters in the s1 are present in s2. The character’s position doesn’t matter.
#
# Given:
#
# Case 1:
#
# s1 = "Yn"
# s2 = "PYnative"
#
# Expected Output:
#
# True
#
# Case 2:
#
# s1 = "Ynf"
# s2 = "PYnative"

# %%
s1 = input("Enter first string: ")
s2 = input("Enter Second String: ")
flag = True
for char in s1:
    if char in s2:
        continue
    else:
        flag = False
print(flag)
# Out:
# Enter first string:  yn
# Enter Second String:  Pynative
# True
