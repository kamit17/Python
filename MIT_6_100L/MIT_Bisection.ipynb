# %%
#  approximation method code to find the square root
x = 0.5
epsilon = 0.01
num_guesses = 0
low = 0
high = x
guess = (high + low)/2.0
while abs(guess**2 - x ) >= epsilon:
    print(f"low= {low}, high = {high},guess = {guess}")
    if guess**2 < x:
        low = guess
    else:
        high = guess
    guess = (high + low) /2.0
    num_guesses += 1
print(f"num_guesses = {num_guesses}")
print(f"{guess} is  close to square root of {x}")

# %%
#####################
## fast square root using bisection search
#####################

x = 0.5
epsilon = 0.01
num_guesses = 0
low = x
high = 1
guess = (high + low)/2.0
while abs(guess**2 - x ) >= epsilon:
    print(f"low= {low}, high = {high},guess = {guess}")
    if guess**2 < x:
        low = guess
    else:
        high = guess
    guess = (high + low) /2.0
    num_guesses += 1
print(f"num_guesses = {num_guesses}")
print(f"{guess} is  close to square root of {x}")

# %%
#####################
## square root with all x values
#####################
x = float(input("Enter any number: "))
epsilon = 0.01
if x >= 1:
    low = 1.0
    high = x
else:
    low = x
    high = 1.0
num_guesses = 0
#low = x
#high = 1
guess = (high + low)/2.0
while abs(guess**2 - x ) >= epsilon:
    #print(f"low= {low}, high = {high},guess = {guess}")
    if guess**2 < x:
        low = guess
    else:
        high = guess
    guess = (high + low) /2.0
    num_guesses += 1
print(f"num_guesses = {num_guesses}")
print(f"{guess} is  close to square root of {x}")

# %%
######## Cube root for all cubes ############
cube = 27
epsilon = 0.01
num_guesses = 0
low = 0
high = cube
guess = (high + low)/2.0
while abs(guess**3 - cube ) > epsilon:
    #print(f"low= {low}, high = {high},guess = {guess}")
    if guess**3 > cube:
        high = guess
        #low = guess
    else:
        low = guess
    guess = (high + low) /2.0
    num_guesses += 1
print(f"num_guesses = {num_guesses}")
print(f"{guess} is  close to cube root of {x}")

# %%
##Newton Raphson Method
epsilon = 0.01
k = 24
guess = k/2.0
num_guesses = 0

while abs(guess*guess - k ) >= epsilon:
    num_guesses += 1
    guess = guess - (((guess**2) - k)/(2*guess))
print(f'num_guesses = {str(num_guesses)}')
print(f'Square root of {str(k)} is about {str(guess)}')
