# %%
new_L = [len(x) for x in ['xy','abcd',7,'4.0'] if type(x) == str]
print(new_L)

# %%
#bisection takes in x and an epsilon
def bisection_root_new(x,epsilon):
    num_guesses = 0
    low = 0
    high = x
    guess = (high + low)/2.0
    while abs(guess**2 - x ) >= epsilon:
        if guess**2 < x:
            low = guess
        else:
            high = guess
        guess = (high + low)/2.0
        num_guesses += 1
    print("num_guesses = ",num_guesses)
    return guess
print(bisection_root_new(123,0.01))

# %%
#epsilon as a keyword parameter
def bisection_root_new(x,epsilon= 0.1):
    num_guesses = 0
    low = 0
    high = x
    guess = (high + low)/2.0
    while abs(guess**2 - x ) >= epsilon:
        if guess**2 < x:
            low = guess
        else:
            high = guess
        guess = (high + low)/2.0
        num_guesses += 1
    print("num_guesses = ",num_guesses)
    return guess
print(bisection_root_new(123))  
print(bisection_root_new(123,0.01))

# %%
#function returning a function
def make_prod(a):
    def g(b):
        return a*b
    return g

#val = make_prod(2)(3)
#print(val)

doubler = make_prod(2)
val = doubler(3)
print(val)

# %%
#Debugging faulty code

def is_pal(x):
    """Returns True if list x is a palindrome and False otherwise"""
    temp = x
    temp.reverse
    if temp == x:
        return True
    else:
        return False

#
